# %% [markdown]
# # DATA CLEANING AND PREPROCESSING

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import OneHotEncoder,LabelEncoder,OrdinalEncoder,StandardScaler
from sklearn.impute import SimpleImputer
from sklearn.compose import ColumnTransformer
from datetime import datetime
import urllib.request
from bs4 import BeautifulSoup
import json
from urllib.request import Request, urlopen
import numpy as np
import pandas as pd
import ssl
import requests
from statistics import mean
import time
import warnings
warnings.filterwarnings("ignore")

# %%
input_file = 'plans_v3.2.xlsx'

# %%
to_process = ["Commercial", "Medicare", "State_medicaid", "Health_Exchange", "Managed medicaid"]

# %%
def melt(df):
    df.reset_index(inplace=True)
    return pd.melt(df,id_vars=['index'])

# %%
def clean_percentage_data(df_status):
    df_status = df_status.astype(str)
    for col in df_status.columns:
        if "unnamed" in col.lower():
            df_status = df_status.drop(col, axis=1)

    df_p = df_status.drop("# of Plans", axis=1)

    # Dropping unnecessary columns and rows and creating separate dataframes for analysis
    df_p = df_p.iloc[:-2,:]
    truncate_idx = df_p.shape[0]
    for col in df_p.columns[1:]:
        for idx, i in enumerate(range(len(df_p[col].values))):
            parts = str(df_p[col].values[i]).split('%')
            if len(parts)==1:
                truncate_idx = min(idx,truncate_idx)
            df_p[col].values[i] = parts[0]

    df_p = df_p.iloc[:truncate_idx]

    df_p.rename(columns = {'Payer/PBM':'Trade Name'},inplace=True)
    df_pt = df_p.transpose()
    new_header = df_pt.iloc[0]
    df_pt = df_pt[1:] 
    df_pt.columns = new_header
    return df_pt.astype(float)

# %%
def clean_coverage_data(df_status):
    df_status = df_status.astype(str)
    for col in df_status.columns:
        if "unnamed" in col.lower():
            df_status = df_status.drop(col, axis=1)

    df_c = df_status.drop("# of Plans", axis=1)
    df_c = df_c.iloc[:-2,:]
    #truncate_idx = df_p.shape[0]
    for col in df_c.columns[1:]:
        for idx, i in enumerate(range(len(df_c[col].values))):
            status = ""
            if "not covered" in str(df_c[col].values[i]).lower():
                status = "Not Covered"
            elif "covered (pa/st)" in str(df_c[col].values[i]).lower():
                status = "Covered (PA/ST)"
            elif "covered" in str(df_c[col].values[i]).lower():
                status = "Covered"
            elif "preferred (pa/st)" in str(df_c[col].values[i]).lower():
                status = "Preferred (PA/ST)"
            elif "preferred" in str(df_c[col].values[i]).lower():
                status = "Preferred"
            else:
                status = "Other"
            df_c[col].values[i] = status

    df_c.rename(columns = {'Payer/PBM':'Trade Name'},inplace=True)
    df_ct = df_c.transpose()
    new_header = df_ct.iloc[0]
    df_ct = df_ct[1:] 
    df_ct.columns = new_header 
    return df_ct

# %%
def get_plans(df_status):
    #df_status = df_status.astype(str)
    for col in df_status.columns:
        if "unnamed" in col.lower():
            df_status = df_status.drop(col, axis=1)
    df_status = df_status.iloc[:-2,:]
    df_status = df_status[['Payer/PBM','# of Plans']]
    df_status['# of Plans'] = df_status['# of Plans'].str.split(' ').str[0]
    df_status['# of Plans'] = df_status['# of Plans'].astype('int64')
    return df_status

# %% [markdown]
# ## Commercial

# %%
sheet_name = to_process[0]
print (sheet_name)
df = pd.read_excel(input_file,sheet_name = sheet_name)
df.head(10)
# Out:
# Commercial
#                                         Payer/PBM  # of Plans  \
# 0                              CVS Health (Aetna)  1217 plans
# 1                             Express Scripts PBM  1179 plans
# 2                        UnitedHealth Group, Inc.   119 plans
# 3                               Cigna Corporation    68 plans
# 4                                         OptumRx   206 plans
# 5                 Department of Defense - TRICARE     5 plans
# 6            Kaiser Foundation Health Plans, Inc.    41 plans
# 7                                    Anthem, Inc.   198 plans
# 8  Blue Cross Blue Shield Association Corporation     6 plans
# 9                 Health Care Service Corporation   115 plans
#
#                 Vijoice               Fyarro             Carvykti  \
# 0       72% Not Covered      96% Not Covered     100% Not Covered
# 1       96% Not Covered  93% Covered (PA/ST)  91% Covered (PA/ST)
# 2   97% Covered (PA/ST)     100% Not Covered     100% Not Covered
# 3      100% Not Covered  95% Covered (PA/ST)     100% Not Covered
# 4   66% Covered (PA/ST)  78% Covered (PA/ST)  66% Covered (PA/ST)
# 5  100% Covered (PA/ST)     100% Not Covered     100% Not Covered
# 6           71% Covered          71% Covered          71% Covered
# 7  100% Covered (PA/ST)  98% Covered (PA/ST)      98% Not Covered
# 8  100% Covered (PA/ST)     100% Not Covered     100% Not Covered
# 9      100% Not Covered     100% Not Covered     100% Not Covered
#
#               Tecartus               Enhertu                Exkivity  \
# 0      85% Not Covered   75% Covered (PA/ST)     85% Covered (PA/ST)
# 1  91% Covered (PA/ST)           50% Covered     91% Covered (PA/ST)
# 2          99% Covered           99% Covered    100% Covered (PA/ST)
# 3      95% Not Covered   97% Covered (PA/ST)     97% Covered (PA/ST)
# 4  69% Covered (PA/ST)   78% Covered (PA/ST)     80% Covered (PA/ST)
# 5     100% Not Covered      100% Not Covered  100% Preferred (PA/ST)
# 6          72% Covered         71% Preferred             72% Covered
# 7      98% Not Covered  100% Covered (PA/ST)    100% Covered (PA/ST)
# 8          99% Covered  100% Covered (PA/ST)    100% Covered (PA/ST)
# 9     100% Not Covered      100% Not Covered     51% Covered (PA/ST)
#
#               Pluvicto              Cabometyx  ...                 Ayvakit  \
# 0     100% Not Covered  69% Preferred (PA/ST)  ...     73% Covered (PA/ST)
# 1      97% Not Covered  68% Preferred (PA/ST)  ...     97% Covered (PA/ST)
# 2     100% Not Covered    82% Covered (PA/ST)  ...     99% Covered (PA/ST)
# 3     100% Not Covered    59% Covered (PA/ST)  ...    100% Covered (PA/ST)
# 4      97% Not Covered  95% Preferred (PA/ST)  ...     80% Covered (PA/ST)
# 5         100% Covered         100% Preferred  ...  100% Preferred (PA/ST)
# 6     100% Not Covered          58% Preferred  ...         80% Not Covered
# 7  98% Covered (PA/ST)  98% Preferred (PA/ST)  ...    100% Covered (PA/ST)
# 8     100% Not Covered    99% Covered (PA/ST)  ...    100% Covered (PA/ST)
# 9     100% Not Covered   100% Covered (PA/ST)  ...     99% Covered (PA/ST)
#
#                    Tukysa                 Qinlock               Bavencio  \
# 0     81% Covered (PA/ST)     71% Covered (PA/ST)    68% Covered (PA/ST)
# 1     94% Covered (PA/ST)         92% Not Covered  66% Preferred (PA/ST)
# 2     89% Covered (PA/ST)     97% Covered (PA/ST)           100% Covered
# 3    100% Covered (PA/ST)     97% Covered (PA/ST)        77% Not Covered
# 4    100% Covered (PA/ST)     82% Covered (PA/ST)    78% Covered (PA/ST)
# 5  100% Preferred (PA/ST)  100% Preferred (PA/ST)       100% Not Covered
# 6           54% Preferred             72% Covered            73% Covered
# 7    100% Covered (PA/ST)    100% Covered (PA/ST)   100% Covered (PA/ST)
# 8     99% Covered (PA/ST)    100% Covered (PA/ST)   100% Covered (PA/ST)
# 9     95% Covered (PA/ST)     99% Covered (PA/ST)        51% Not Covered
#
#                 Blincyto                Cosela               Jelmyto  \
# 0    79% Covered (PA/ST)       65% Not Covered       89% Not Covered
# 1  67% Preferred (PA/ST)       89% Not Covered   92% Covered (PA/ST)
# 2            99% Covered          100% Covered          100% Covered
# 3        77% Not Covered       95% Not Covered   97% Covered (PA/ST)
# 4    78% Covered (PA/ST)           80% Covered           79% Covered
# 5       100% Not Covered      100% Not Covered      100% Not Covered
# 6            48% Covered           72% Covered       84% Not Covered
# 7   100% Covered (PA/ST)  100% Covered (PA/ST)  100% Covered (PA/ST)
# 8    99% Covered (PA/ST)   99% Covered (PA/ST)           99% Covered
# 9        94% Not Covered       51% Not Covered       88% Not Covered
#
#                  Polivy               Rozlytrek                 Turalio
# 0   68% Covered (PA/ST)   68% Preferred (PA/ST)     68% Covered (PA/ST)
# 1           94% Covered   92% Preferred (PA/ST)             91% Covered
# 2          100% Covered   91% Preferred (PA/ST)             90% Covered
# 3       77% Not Covered     97% Covered (PA/ST)     95% Covered (PA/ST)
# 4   78% Covered (PA/ST)    100% Covered (PA/ST)     80% Covered (PA/ST)
# 5      100% Not Covered  100% Preferred (PA/ST)  100% Preferred (PA/ST)
# 6           72% Covered           54% Preferred             72% Covered
# 7   98% Covered (PA/ST)     98% Covered (PA/ST)     98% Covered (PA/ST)
# 8  100% Covered (PA/ST)     99% Covered (PA/ST)     99% Covered (PA/ST)
# 9      100% Not Covered     98% Covered (PA/ST)     84% Covered (PA/ST)
#
# [10 rows x 84 columns]

# %%
df_commercial_p = clean_percentage_data(df) # Commercial
df_commercial_p
# Out:
# Trade Name  CVS Health (Aetna)  Express Scripts PBM  UnitedHealth Group, Inc.  \
# Vijoice                   72.0                 96.0                      97.0
# Fyarro                    96.0                 93.0                     100.0
# Carvykti                 100.0                 91.0                     100.0
# Tecartus                  85.0                 91.0                      99.0
# Enhertu                   75.0                 50.0                      99.0
# ...                        ...                  ...                       ...
# Cosela                    65.0                 89.0                     100.0
# Jelmyto                   89.0                 92.0                     100.0
# Polivy                    68.0                 94.0                     100.0
# Rozlytrek                 68.0                 92.0                      91.0
# Turalio                   68.0                 91.0                      90.0
#
# Trade Name  Cigna Corporation  OptumRx  Department of Defense - TRICARE  \
# Vijoice                 100.0     66.0                            100.0
# Fyarro                   95.0     78.0                            100.0
# Carvykti                100.0     66.0                            100.0
# Tecartus                 95.0     69.0                            100.0
# Enhertu                  97.0     78.0                            100.0
# ...                       ...      ...                              ...
# Cosela                   95.0     80.0                            100.0
# Jelmyto                  97.0     79.0                            100.0
# Polivy                   77.0     78.0                            100.0
# Rozlytrek                97.0    100.0                            100.0
# Turalio                  95.0     80.0                            100.0
#
# Trade Name  Kaiser Foundation Health Plans, Inc.  Anthem, Inc.  \
# Vijoice                                     71.0         100.0
# Fyarro                                      71.0          98.0
# Carvykti                                    71.0          98.0
# Tecartus                                    72.0          98.0
# Enhertu                                     71.0         100.0
# ...                                          ...           ...
# Cosela                                      72.0         100.0
# Jelmyto                                     84.0         100.0
# Polivy                                      72.0          98.0
# Rozlytrek                                   54.0          98.0
# Turalio                                     72.0          98.0
#
# Trade Name  Blue Cross Blue Shield Association Corporation  \
# Vijoice                                              100.0
# Fyarro                                               100.0
# Carvykti                                             100.0
# Tecartus                                              99.0
# Enhertu                                              100.0
# ...                                                    ...
# Cosela                                                99.0
# Jelmyto                                               99.0
# Polivy                                               100.0
# Rozlytrek                                             99.0
# Turalio                                               99.0
#
# Trade Name  Health Care Service Corporation  ...  Alameda Alliance for Health  \
# Vijoice                               100.0  ...                        100.0
# Fyarro                                100.0  ...                        100.0
# Carvykti                              100.0  ...                        100.0
# Tecartus                              100.0  ...                        100.0
# Enhertu                               100.0  ...                        100.0
# ...                                     ...  ...                          ...
# Cosela                                 51.0  ...                        100.0
# Jelmyto                                88.0  ...                        100.0
# Polivy                                100.0  ...                        100.0
# Rozlytrek                              98.0  ...                        100.0
# Turalio                                84.0  ...                        100.0
#
# Trade Name  GlobalHealth, Inc.  Chinese Community Health Plan Corporation  \
# Vijoice                  100.0                                      100.0
# Fyarro                   100.0                                      100.0
# Carvykti                 100.0                                      100.0
# Tecartus                 100.0                                      100.0
# Enhertu                  100.0                                      100.0
# ...                        ...                                        ...
# Cosela                   100.0                                      100.0
# Jelmyto                  100.0                                      100.0
# Polivy                   100.0                                      100.0
# Rozlytrek                100.0                                      100.0
# Turalio                  100.0                                      100.0
#
# Trade Name  Washtenaw Health Plan  Samaritan Health Services  \
# Vijoice                     100.0                      100.0
# Fyarro                      100.0                      100.0
# Carvykti                    100.0                      100.0
# Tecartus                    100.0                       60.0
# Enhertu                     100.0                      100.0
# ...                           ...                        ...
# Cosela                      100.0                       60.0
# Jelmyto                     100.0                       60.0
# Polivy                      100.0                      100.0
# Rozlytrek                   100.0                      100.0
# Turalio                     100.0                      100.0
#
# Trade Name  Santa Cruz-Monterey Managed Medical Care Commission  \
# Vijoice                                                 100.0
# Fyarro                                                  100.0
# Carvykti                                                100.0
# Tecartus                                                100.0
# Enhertu                                                 100.0
# ...                                                       ...
# Cosela                                                  100.0
# Jelmyto                                                 100.0
# Polivy                                                  100.0
# Rozlytrek                                               100.0
# Turalio                                                 100.0
#
# Trade Name  ClearScript PBM  University Health System Inc.  \
# Vijoice               100.0                          100.0
# Fyarro                100.0                          100.0
# Carvykti              100.0                          100.0
# Tecartus              100.0                          100.0
# Enhertu               100.0                          100.0
# ...                     ...                            ...
# Cosela                100.0                          100.0
# Jelmyto               100.0                          100.0
# Polivy                100.0                          100.0
# Rozlytrek             100.0                          100.0
# Turalio               100.0                          100.0
#
# Trade Name  Global Pharmaceutical Benefits  \
# Vijoice                              100.0
# Fyarro                               100.0
# Carvykti                             100.0
# Tecartus                             100.0
# Enhertu                              100.0
# ...                                    ...
# Cosela                               100.0
# Jelmyto                              100.0
# Polivy                               100.0
# Rozlytrek                            100.0
# Turalio                              100.0
#
# Trade Name  Centers for Disease Control and Prevention
# Vijoice                                          100.0
# Fyarro                                           100.0
# Carvykti                                         100.0
# Tecartus                                         100.0
# Enhertu                                          100.0
# ...                                                ...
# Cosela                                           100.0
# Jelmyto                                          100.0
# Polivy                                           100.0
# Rozlytrek                                        100.0
# Turalio                                          100.0
#
# [82 rows x 163 columns]

# %%
df_commercial_c = clean_coverage_data(df) # Commercial
df_commercial_c
# Out:
# Trade Name CVS Health (Aetna) Express Scripts PBM UnitedHealth Group, Inc.  \
# Vijoice           Not Covered         Not Covered          Covered (PA/ST)
# Fyarro            Not Covered     Covered (PA/ST)              Not Covered
# Carvykti          Not Covered     Covered (PA/ST)              Not Covered
# Tecartus          Not Covered     Covered (PA/ST)                  Covered
# Enhertu       Covered (PA/ST)             Covered                  Covered
# ...                       ...                 ...                      ...
# Cosela            Not Covered         Not Covered                  Covered
# Jelmyto           Not Covered     Covered (PA/ST)                  Covered
# Polivy        Covered (PA/ST)             Covered                  Covered
# Rozlytrek   Preferred (PA/ST)   Preferred (PA/ST)        Preferred (PA/ST)
# Turalio       Covered (PA/ST)             Covered                  Covered
#
# Trade Name Cigna Corporation          OptumRx Department of Defense - TRICARE  \
# Vijoice          Not Covered  Covered (PA/ST)                 Covered (PA/ST)
# Fyarro       Covered (PA/ST)  Covered (PA/ST)                     Not Covered
# Carvykti         Not Covered  Covered (PA/ST)                     Not Covered
# Tecartus         Not Covered  Covered (PA/ST)                     Not Covered
# Enhertu      Covered (PA/ST)  Covered (PA/ST)                     Not Covered
# ...                      ...              ...                             ...
# Cosela           Not Covered          Covered                     Not Covered
# Jelmyto      Covered (PA/ST)          Covered                     Not Covered
# Polivy           Not Covered  Covered (PA/ST)                     Not Covered
# Rozlytrek    Covered (PA/ST)  Covered (PA/ST)               Preferred (PA/ST)
# Turalio      Covered (PA/ST)  Covered (PA/ST)               Preferred (PA/ST)
#
# Trade Name Kaiser Foundation Health Plans, Inc.     Anthem, Inc.  \
# Vijoice                                 Covered  Covered (PA/ST)
# Fyarro                                  Covered  Covered (PA/ST)
# Carvykti                                Covered      Not Covered
# Tecartus                                Covered      Not Covered
# Enhertu                               Preferred  Covered (PA/ST)
# ...                                         ...              ...
# Cosela                                  Covered  Covered (PA/ST)
# Jelmyto                             Not Covered  Covered (PA/ST)
# Polivy                                  Covered  Covered (PA/ST)
# Rozlytrek                             Preferred  Covered (PA/ST)
# Turalio                                 Covered  Covered (PA/ST)
#
# Trade Name Blue Cross Blue Shield Association Corporation  \
# Vijoice                                   Covered (PA/ST)
# Fyarro                                        Not Covered
# Carvykti                                      Not Covered
# Tecartus                                          Covered
# Enhertu                                   Covered (PA/ST)
# ...                                                   ...
# Cosela                                    Covered (PA/ST)
# Jelmyto                                           Covered
# Polivy                                    Covered (PA/ST)
# Rozlytrek                                 Covered (PA/ST)
# Turalio                                   Covered (PA/ST)
#
# Trade Name Health Care Service Corporation  ... MedalistRx PBM  \
# Vijoice                        Not Covered  ...    Not Covered
# Fyarro                         Not Covered  ...    Not Covered
# Carvykti                       Not Covered  ...    Not Covered
# Tecartus                       Not Covered  ...        Covered
# Enhertu                        Not Covered  ...        Covered
# ...                                    ...  ...            ...
# Cosela                         Not Covered  ...        Covered
# Jelmyto                        Not Covered  ...        Covered
# Polivy                         Not Covered  ...    Not Covered
# Rozlytrek                  Covered (PA/ST)  ...    Not Covered
# Turalio                    Covered (PA/ST)  ...        Covered
#
# Trade Name Citizens Rx PBM     PharmPix TrueScripts PBM Pharmavail PBM  \
# Vijoice        Not Covered  Not Covered     Not Covered    Not Covered
# Fyarro         Not Covered  Not Covered     Not Covered    Not Covered
# Carvykti       Not Covered  Not Covered     Not Covered    Not Covered
# Tecartus           Covered      Covered         Covered        Covered
# Enhertu            Covered      Covered         Covered        Covered
# ...                    ...          ...             ...            ...
# Cosela             Covered      Covered         Covered        Covered
# Jelmyto            Covered      Covered         Covered        Covered
# Polivy             Covered      Covered         Covered        Covered
# Rozlytrek      Not Covered      Covered         Covered        Covered
# Turalio            Covered      Covered         Covered        Covered
#
# Trade Name    Araya PBM Abarca Health   ProAct PBM Prescryptive PBM  \
# Vijoice     Not Covered   Not Covered  Not Covered      Not Covered
# Fyarro      Not Covered   Not Covered  Not Covered      Not Covered
# Carvykti    Not Covered   Not Covered  Not Covered      Not Covered
# Tecartus        Covered       Covered      Covered          Covered
# Enhertu         Covered       Covered      Covered          Covered
# ...                 ...           ...          ...              ...
# Cosela          Covered       Covered      Covered          Covered
# Jelmyto         Covered       Covered      Covered          Covered
# Polivy          Covered       Covered      Covered          Covered
# Rozlytrek       Covered       Covered      Covered          Covered
# Turalio         Covered       Covered      Covered          Covered
#
# Trade Name     Rightway PBM
# Vijoice     Covered (PA/ST)
# Fyarro          Not Covered
# Carvykti        Not Covered
# Tecartus            Covered
# Enhertu             Covered
# ...                     ...
# Cosela              Covered
# Jelmyto             Covered
# Polivy              Covered
# Rozlytrek           Covered
# Turalio             Covered
#
# [82 rows x 188 columns]

# %%
df_commercial_num = get_plans(df) # Commercial
df_commercial_num
# Out:
#                     Payer/PBM  # of Plans
# 0          CVS Health (Aetna)        1217
# 1         Express Scripts PBM        1179
# 2    UnitedHealth Group, Inc.         119
# 3           Cigna Corporation          68
# 4                     OptumRx         206
# ..                        ...         ...
# 183                 Araya PBM           2
# 184             Abarca Health           1
# 185                ProAct PBM           6
# 186          Prescryptive PBM           1
# 187              Rightway PBM           1
#
# [188 rows x 2 columns]

# %% [markdown]
# ## Medicare

# %%
sheet_name = to_process[1]
print (sheet_name)
df = pd.read_excel(input_file,sheet_name = sheet_name)
df.head(10)
# Out:
# Medicare
#                               Payer/PBM # of Plans              Vijoice   \
# 0              UnitedHealth Group, Inc.  132 plans      100% Not Covered
# 1                    CVS Health (Aetna)  137 plans       90% Not Covered
# 2                          Humana, Inc.   95 plans       93% Not Covered
# 3                   Centene Corporation  188 plans      100% Not Covered
# 4                          Anthem, Inc.  166 plans       86% Not Covered
# 5                     Cigna Corporation   28 plans      100% Not Covered
# 6  Kaiser Foundation Health Plans, Inc.   70 plans           95% Covered
# 7                   Express Scripts PBM    4 plans       50% Not Covered
# 8                      Elixir Insurance    3 plans  100% Covered (PA/ST)
# 9                               OptumRx    3 plans   59% Covered (PA/ST)
#
#                Fyarro          Carvykti          Tecartus   \
# 0     100% Not Covered  100% Not Covered  100% Not Covered
# 1     100% Not Covered  100% Not Covered  100% Not Covered
# 2     100% Not Covered   93% Not Covered  100% Not Covered
# 3     100% Not Covered  100% Not Covered  100% Not Covered
# 4     100% Not Covered  100% Not Covered  100% Not Covered
# 5     100% Not Covered  100% Not Covered  100% Not Covered
# 6          95% Covered  100% Not Covered  100% Not Covered
# 7     100% Not Covered  100% Not Covered  100% Not Covered
# 8     100% Not Covered  100% Not Covered  100% Not Covered
# 9  59% Covered (PA/ST)  100% Not Covered  100% Not Covered
#
#                Enhertu              Exkivity          Pluvicto   \
# 0      100% Not Covered   78% Covered (PA/ST)  100% Not Covered
# 1       62% Not Covered   75% Covered (PA/ST)  100% Not Covered
# 2   58% Covered (PA/ST)  100% Covered (PA/ST)  100% Not Covered
# 3      100% Not Covered   99% Covered (PA/ST)  100% Not Covered
# 4   86% Covered (PA/ST)   93% Covered (PA/ST)  100% Not Covered
# 5   95% Covered (PA/ST)   95% Covered (PA/ST)  100% Not Covered
# 6           95% Covered           95% Covered  100% Not Covered
# 7      100% Not Covered   56% Covered (PA/ST)  100% Not Covered
# 8      100% Not Covered  100% Covered (PA/ST)  100% Not Covered
# 9  100% Covered (PA/ST)   59% Covered (PA/ST)  100% Not Covered
#
#              Cabometyx   ...               Tukysa               Qinlock   \
# 0   82% Covered (PA/ST)  ...           81% Covered   78% Covered (PA/ST)
# 1   99% Covered (PA/ST)  ...  100% Covered (PA/ST)   93% Covered (PA/ST)
# 2  100% Covered (PA/ST)  ...  100% Covered (PA/ST)  100% Covered (PA/ST)
# 3   99% Covered (PA/ST)  ...   99% Covered (PA/ST)   99% Covered (PA/ST)
# 4   93% Covered (PA/ST)  ...   93% Covered (PA/ST)   93% Covered (PA/ST)
# 5   95% Covered (PA/ST)  ...   95% Covered (PA/ST)   95% Covered (PA/ST)
# 6           89% Covered  ...           95% Covered           95% Covered
# 7   56% Covered (PA/ST)  ...   68% Covered (PA/ST)   68% Covered (PA/ST)
# 8  100% Covered (PA/ST)  ...  100% Covered (PA/ST)  100% Covered (PA/ST)
# 9  100% Covered (PA/ST)  ...  100% Covered (PA/ST)  100% Covered (PA/ST)
#
#              Bavencio             Blincyto            Cosela   \
# 0      95% Not Covered     100% Not Covered  100% Not Covered
# 1      90% Not Covered      74% Not Covered  100% Not Covered
# 2  58% Covered (PA/ST)     100% Not Covered  100% Not Covered
# 3     100% Not Covered     100% Not Covered  100% Not Covered
# 4  86% Covered (PA/ST)  71% Covered (PA/ST)  100% Not Covered
# 5  95% Covered (PA/ST)          95% Covered  100% Not Covered
# 6          95% Covered      89% Not Covered       89% Covered
# 7      63% Not Covered      63% Not Covered  100% Not Covered
# 8     100% Not Covered     100% Not Covered  100% Not Covered
# 9  41% Covered (PA/ST)  76% Covered (PA/ST)  100% Not Covered
#
#            Jelmyto                Polivy             Rozlytrek   \
# 0  100% Not Covered      100% Not Covered   78% Covered (PA/ST)
# 1  100% Not Covered       62% Not Covered  100% Covered (PA/ST)
# 2  100% Not Covered   58% Covered (PA/ST)  100% Covered (PA/ST)
# 3  100% Not Covered      100% Not Covered   99% Covered (PA/ST)
# 4  100% Not Covered   86% Covered (PA/ST)   93% Covered (PA/ST)
# 5  100% Not Covered   95% Covered (PA/ST)   95% Covered (PA/ST)
# 6  100% Not Covered           95% Covered           95% Covered
# 7  100% Not Covered       63% Not Covered   68% Covered (PA/ST)
# 8  100% Not Covered      100% Not Covered  100% Covered (PA/ST)
# 9  100% Not Covered  100% Covered (PA/ST)  100% Covered (PA/ST)
#
#                Turalio              Pemazyre
# 0   78% Covered (PA/ST)   78% Covered (PA/ST)
# 1  100% Covered (PA/ST)  100% Covered (PA/ST)
# 2  100% Covered (PA/ST)  100% Covered (PA/ST)
# 3   99% Covered (PA/ST)   99% Covered (PA/ST)
# 4   93% Covered (PA/ST)   93% Covered (PA/ST)
# 5   95% Covered (PA/ST)   95% Covered (PA/ST)
# 6           95% Covered           95% Covered
# 7   68% Covered (PA/ST)   68% Covered (PA/ST)
# 8  100% Covered (PA/ST)  100% Covered (PA/ST)
# 9  100% Covered (PA/ST)  100% Covered (PA/ST)
#
# [10 rows x 84 columns]

# %%
df_medicare_p = clean_percentage_data(df) # Medicare
df_medicare_p
# Out:
# Trade Name  UnitedHealth Group, Inc.  CVS Health (Aetna)  Humana, Inc.  \
# Vijoice                        100.0                90.0          93.0
# Fyarro                         100.0               100.0         100.0
# Carvykti                       100.0               100.0          93.0
# Tecartus                       100.0               100.0         100.0
# Enhertu                        100.0                62.0          58.0
# ...                              ...                 ...           ...
# Jelmyto                        100.0               100.0         100.0
# Polivy                         100.0                62.0          58.0
# Rozlytrek                       78.0               100.0         100.0
# Turalio                         78.0               100.0         100.0
# Pemazyre                        78.0               100.0         100.0
#
# Trade Name  Centene Corporation  Anthem, Inc.  Cigna Corporation  \
# Vijoice                   100.0          86.0              100.0
# Fyarro                    100.0         100.0              100.0
# Carvykti                  100.0         100.0              100.0
# Tecartus                  100.0         100.0              100.0
# Enhertu                   100.0          86.0               95.0
# ...                         ...           ...                ...
# Jelmyto                   100.0         100.0              100.0
# Polivy                    100.0          86.0               95.0
# Rozlytrek                  99.0          93.0               95.0
# Turalio                    99.0          93.0               95.0
# Pemazyre                   99.0          93.0               95.0
#
# Trade Name  Kaiser Foundation Health Plans, Inc.  Express Scripts PBM  \
# Vijoice                                     95.0                 50.0
# Fyarro                                      95.0                100.0
# Carvykti                                   100.0                100.0
# Tecartus                                   100.0                100.0
# Enhertu                                     95.0                100.0
# ...                                          ...                  ...
# Jelmyto                                    100.0                100.0
# Polivy                                      95.0                 63.0
# Rozlytrek                                   95.0                 68.0
# Turalio                                     95.0                 68.0
# Pemazyre                                    95.0                 68.0
#
# Trade Name  Elixir Insurance  OptumRx  ...  Aspirus Health Care  \
# Vijoice                100.0     59.0  ...                100.0
# Fyarro                 100.0     59.0  ...                100.0
# Carvykti               100.0    100.0  ...                100.0
# Tecartus               100.0    100.0  ...                100.0
# Enhertu                100.0    100.0  ...                100.0
# ...                      ...      ...  ...                  ...
# Jelmyto                100.0    100.0  ...                100.0
# Polivy                 100.0    100.0  ...                100.0
# Rozlytrek              100.0    100.0  ...                100.0
# Turalio                100.0    100.0  ...                100.0
# Pemazyre               100.0    100.0  ...                100.0
#
# Trade Name  Vitality Health Plan of California  RiverSpring Health Plans  \
# Vijoice                                  100.0                     100.0
# Fyarro                                   100.0                     100.0
# Carvykti                                 100.0                     100.0
# Tecartus                                 100.0                     100.0
# Enhertu                                  100.0                     100.0
# ...                                        ...                       ...
# Jelmyto                                  100.0                     100.0
# Polivy                                   100.0                     100.0
# Rozlytrek                                100.0                      61.0
# Turalio                                  100.0                      61.0
# Pemazyre                                 100.0                      61.0
#
# Trade Name  Community Health Choice, Inc.  Dignity Health Plan  \
# Vijoice                             100.0                100.0
# Fyarro                              100.0                100.0
# Carvykti                            100.0                100.0
# Tecartus                            100.0                100.0
# Enhertu                             100.0                100.0
# ...                                   ...                  ...
# Jelmyto                             100.0                100.0
# Polivy                              100.0                100.0
# Rozlytrek                           100.0                100.0
# Turalio                             100.0                100.0
# Pemazyre                            100.0                100.0
#
# Trade Name  McLaren Health Care Corporation  Nascentia Health, Inc.  \
# Vijoice                               100.0                   100.0
# Fyarro                                100.0                   100.0
# Carvykti                              100.0                   100.0
# Tecartus                              100.0                   100.0
# Enhertu                                54.0                   100.0
# ...                                     ...                     ...
# Jelmyto                               100.0                   100.0
# Polivy                                 54.0                   100.0
# Rozlytrek                              54.0                   100.0
# Turalio                                54.0                   100.0
# Pemazyre                               54.0                   100.0
#
# Trade Name  Sonder Health Plans, Inc.  El Paso HealthPlans, Inc.  \
# Vijoice                         100.0                      100.0
# Fyarro                          100.0                      100.0
# Carvykti                        100.0                      100.0
# Tecartus                        100.0                      100.0
# Enhertu                         100.0                      100.0
# ...                               ...                        ...
# Jelmyto                         100.0                      100.0
# Polivy                          100.0                      100.0
# Rozlytrek                       100.0                      100.0
# Turalio                         100.0                      100.0
# Pemazyre                        100.0                      100.0
#
# Trade Name  University Health System Inc.
# Vijoice                             100.0
# Fyarro                              100.0
# Carvykti                            100.0
# Tecartus                            100.0
# Enhertu                             100.0
# ...                                   ...
# Jelmyto                             100.0
# Polivy                              100.0
# Rozlytrek                           100.0
# Turalio                             100.0
# Pemazyre                            100.0
#
# [82 rows x 204 columns]

# %%
df_medicare_c = clean_coverage_data(df) # Medicare
df_medicare_c
# Out:
# Trade Name UnitedHealth Group, Inc. CVS Health (Aetna)     Humana, Inc.  \
# Vijoice                 Not Covered        Not Covered      Not Covered
# Fyarro                  Not Covered        Not Covered      Not Covered
# Carvykti                Not Covered        Not Covered      Not Covered
# Tecartus                Not Covered        Not Covered      Not Covered
# Enhertu                 Not Covered        Not Covered  Covered (PA/ST)
# ...                             ...                ...              ...
# Jelmyto                 Not Covered        Not Covered      Not Covered
# Polivy                  Not Covered        Not Covered  Covered (PA/ST)
# Rozlytrek           Covered (PA/ST)    Covered (PA/ST)  Covered (PA/ST)
# Turalio             Covered (PA/ST)    Covered (PA/ST)  Covered (PA/ST)
# Pemazyre            Covered (PA/ST)    Covered (PA/ST)  Covered (PA/ST)
#
# Trade Name Centene Corporation     Anthem, Inc. Cigna Corporation  \
# Vijoice            Not Covered      Not Covered       Not Covered
# Fyarro             Not Covered      Not Covered       Not Covered
# Carvykti           Not Covered      Not Covered       Not Covered
# Tecartus           Not Covered      Not Covered       Not Covered
# Enhertu            Not Covered  Covered (PA/ST)   Covered (PA/ST)
# ...                        ...              ...               ...
# Jelmyto            Not Covered      Not Covered       Not Covered
# Polivy             Not Covered  Covered (PA/ST)   Covered (PA/ST)
# Rozlytrek      Covered (PA/ST)  Covered (PA/ST)   Covered (PA/ST)
# Turalio        Covered (PA/ST)  Covered (PA/ST)   Covered (PA/ST)
# Pemazyre       Covered (PA/ST)  Covered (PA/ST)   Covered (PA/ST)
#
# Trade Name Kaiser Foundation Health Plans, Inc. Express Scripts PBM  \
# Vijoice                                 Covered         Not Covered
# Fyarro                                  Covered         Not Covered
# Carvykti                            Not Covered         Not Covered
# Tecartus                            Not Covered         Not Covered
# Enhertu                                 Covered         Not Covered
# ...                                         ...                 ...
# Jelmyto                             Not Covered         Not Covered
# Polivy                                  Covered         Not Covered
# Rozlytrek                               Covered     Covered (PA/ST)
# Turalio                                 Covered     Covered (PA/ST)
# Pemazyre                                Covered     Covered (PA/ST)
#
# Trade Name Elixir Insurance          OptumRx  ... El Paso HealthPlans, Inc.  \
# Vijoice     Covered (PA/ST)  Covered (PA/ST)  ...               Not Covered
# Fyarro          Not Covered  Covered (PA/ST)  ...               Not Covered
# Carvykti        Not Covered      Not Covered  ...               Not Covered
# Tecartus        Not Covered      Not Covered  ...               Not Covered
# Enhertu         Not Covered  Covered (PA/ST)  ...               Not Covered
# ...                     ...              ...  ...                       ...
# Jelmyto         Not Covered      Not Covered  ...               Not Covered
# Polivy          Not Covered  Covered (PA/ST)  ...               Not Covered
# Rozlytrek   Covered (PA/ST)  Covered (PA/ST)  ...           Covered (PA/ST)
# Turalio     Covered (PA/ST)  Covered (PA/ST)  ...           Covered (PA/ST)
# Pemazyre    Covered (PA/ST)  Covered (PA/ST)  ...           Covered (PA/ST)
#
# Trade Name University Health System Inc. Magellan Rx Management  \
# Vijoice                      Not Covered            Not Covered
# Fyarro                       Not Covered            Not Covered
# Carvykti                     Not Covered            Not Covered
# Tecartus                     Not Covered            Not Covered
# Enhertu                      Not Covered            Not Covered
# ...                                  ...                    ...
# Jelmyto                      Not Covered            Not Covered
# Polivy                       Not Covered            Not Covered
# Rozlytrek                Covered (PA/ST)        Covered (PA/ST)
# Turalio                  Covered (PA/ST)        Covered (PA/ST)
# Pemazyre                 Covered (PA/ST)                Covered
#
# Trade Name State of North Carolina Golden State Medicare Health Plan  \
# Vijoice            Covered (PA/ST)                       Not Covered
# Fyarro                 Not Covered                       Not Covered
# Carvykti           Covered (PA/ST)                       Not Covered
# Tecartus               Not Covered                       Not Covered
# Enhertu            Covered (PA/ST)                       Not Covered
# ...                            ...                               ...
# Jelmyto                Not Covered                       Not Covered
# Polivy             Covered (PA/ST)                       Not Covered
# Rozlytrek          Covered (PA/ST)                   Covered (PA/ST)
# Turalio            Covered (PA/ST)                   Covered (PA/ST)
# Pemazyre           Covered (PA/ST)                   Covered (PA/ST)
#
# Trade Name Integra Managed Care Group Health Cooperative Eau Claire  \
# Vijoice         Covered (PA/ST)                         Not Covered
# Fyarro              Not Covered                         Not Covered
# Carvykti            Not Covered                         Not Covered
# Tecartus            Not Covered                         Not Covered
# Enhertu             Not Covered                         Not Covered
# ...                         ...                                 ...
# Jelmyto             Not Covered                         Not Covered
# Polivy              Not Covered                         Not Covered
# Rozlytrek       Covered (PA/ST)                     Covered (PA/ST)
# Turalio         Covered (PA/ST)                     Covered (PA/ST)
# Pemazyre        Covered (PA/ST)                     Covered (PA/ST)
#
# Trade Name    eternalHealth Innovative Integrated Health, Inc.  \
# Vijoice         Not Covered                        Not Covered
# Fyarro          Not Covered                        Not Covered
# Carvykti        Not Covered                        Not Covered
# Tecartus        Not Covered                        Not Covered
# Enhertu         Not Covered                        Not Covered
# ...                     ...                                ...
# Jelmyto         Not Covered                        Not Covered
# Polivy      Covered (PA/ST)                        Not Covered
# Rozlytrek   Covered (PA/ST)                    Covered (PA/ST)
# Turalio     Covered (PA/ST)                    Covered (PA/ST)
# Pemazyre    Covered (PA/ST)                    Covered (PA/ST)
#
# Trade Name       ApexHealth
# Vijoice         Not Covered
# Fyarro          Not Covered
# Carvykti        Not Covered
# Tecartus        Not Covered
# Enhertu     Covered (PA/ST)
# ...                     ...
# Jelmyto         Not Covered
# Polivy      Covered (PA/ST)
# Rozlytrek   Covered (PA/ST)
# Turalio         Not Covered
# Pemazyre    Covered (PA/ST)
#
# [82 rows x 212 columns]

# %%
df_medicare_num = get_plans(df) # Medicare
df_medicare_num
# Out:
#                                Payer/PBM  # of Plans
# 0               UnitedHealth Group, Inc.         132
# 1                     CVS Health (Aetna)         137
# 2                           Humana, Inc.          95
# 3                    Centene Corporation         188
# 4                           Anthem, Inc.         166
# ..                                   ...         ...
# 207                 Integra Managed Care           2
# 208  Group Health Cooperative Eau Claire           2
# 209                        eternalHealth           3
# 210   Innovative Integrated Health, Inc.           1
# 211                           ApexHealth           2
#
# [212 rows x 2 columns]

# %% [markdown]
# ## State_medicaid

# %%
sheet_name = to_process[2]
print (sheet_name)
df = pd.read_excel(input_file,sheet_name = sheet_name)
df.head(10)
# Out:
# State_medicaid
#                 Payer/PBM # of Plans                Vijoice   \
# 0       State of Colorado    7 plans    100% Covered (PA/ST)
# 1       State of Oklahoma    2 plans        100% Not Covered
# 2  State of Massachusetts    2 plans  100% Preferred (PA/ST)
# 3     State of California    2 plans     99% Covered (PA/ST)
# 4        State of Florida    2 plans     98% Covered (PA/ST)
# 5        State of Alabama    2 plans            100% Covered
# 6       State of Arkansas    2 plans    100% Covered (PA/ST)
# 7    State of Connecticut    2 plans    100% Covered (PA/ST)
# 8       State of Michigan    2 plans    100% Covered (PA/ST)
# 9        State of Georgia    2 plans     98% Covered (PA/ST)
#
#                 Fyarro              Carvykti              Tecartus   \
# 0  100% Covered (PA/ST)  100% Covered (PA/ST)  100% Covered (PA/ST)
# 1      100% Not Covered      100% Not Covered  100% Covered (PA/ST)
# 2  100% Covered (PA/ST)      100% Not Covered      100% Not Covered
# 3         99% Preferred   99% Covered (PA/ST)   99% Covered (PA/ST)
# 4   98% Covered (PA/ST)   98% Covered (PA/ST)           98% Covered
# 5      100% Not Covered          100% Covered      100% Not Covered
# 6  100% Covered (PA/ST)  100% Covered (PA/ST)          100% Covered
# 7  100% Covered (PA/ST)  100% Covered (PA/ST)          100% Covered
# 8  100% Covered (PA/ST)  100% Covered (PA/ST)      100% Not Covered
# 9   98% Covered (PA/ST)   98% Covered (PA/ST)           98% Covered
#
#                Enhertu               Exkivity              Pluvicto   \
# 0          100% Covered           100% Covered      100% Not Covered
# 1  100% Covered (PA/ST)   100% Covered (PA/ST)  100% Covered (PA/ST)
# 2  100% Covered (PA/ST)   100% Covered (PA/ST)      100% Not Covered
# 3         99% Preferred          99% Preferred      100% Not Covered
# 4           98% Covered    98% Covered (PA/ST)      100% Not Covered
# 5          100% Covered           100% Covered      100% Not Covered
# 6          100% Covered   100% Covered (PA/ST)      100% Not Covered
# 7          100% Covered         100% Preferred      100% Not Covered
# 8      100% Not Covered           100% Covered      100% Not Covered
# 9           98% Covered  98% Preferred (PA/ST)      100% Not Covered
#
#               Cabometyx   ...               Ayvakit                 Tukysa   \
# 0           100% Covered  ...           100% Covered           100% Covered
# 1   100% Covered (PA/ST)  ...   100% Covered (PA/ST)   100% Covered (PA/ST)
# 2   100% Covered (PA/ST)  ...   100% Covered (PA/ST)   100% Covered (PA/ST)
# 3          99% Preferred  ...          99% Preferred    99% Covered (PA/ST)
# 4    98% Covered (PA/ST)  ...            98% Covered            98% Covered
# 5           100% Covered  ...   100% Covered (PA/ST)           100% Covered
# 6   100% Covered (PA/ST)  ...   100% Covered (PA/ST)   100% Covered (PA/ST)
# 7         100% Preferred  ...         100% Preferred           100% Covered
# 8           100% Covered  ...           100% Covered           100% Covered
# 9  98% Preferred (PA/ST)  ...  98% Preferred (PA/ST)  98% Preferred (PA/ST)
#
#                 Qinlock              Bavencio              Blincyto   \
# 0           100% Covered          100% Covered          100% Covered
# 1   100% Covered (PA/ST)  100% Covered (PA/ST)  100% Covered (PA/ST)
# 2   100% Covered (PA/ST)  100% Covered (PA/ST)  100% Covered (PA/ST)
# 3          99% Preferred         99% Preferred         99% Preferred
# 4            98% Covered   98% Covered (PA/ST)   98% Covered (PA/ST)
# 5           100% Covered          100% Covered          100% Covered
# 6   100% Covered (PA/ST)          100% Covered          100% Covered
# 7         100% Preferred          100% Covered          100% Covered
# 8           100% Covered      100% Not Covered      100% Not Covered
# 9  98% Preferred (PA/ST)           98% Covered           98% Covered
#
#                 Cosela               Jelmyto                Polivy   \
# 0          100% Covered          100% Covered          100% Covered
# 1          100% Covered  100% Covered (PA/ST)  100% Covered (PA/ST)
# 2  100% Covered (PA/ST)      100% Not Covered  100% Covered (PA/ST)
# 3   99% Covered (PA/ST)         99% Preferred         99% Preferred
# 4   98% Covered (PA/ST)   98% Covered (PA/ST)   98% Covered (PA/ST)
# 5      100% Not Covered          100% Covered          100% Covered
# 6          100% Covered          100% Covered          100% Covered
# 7          100% Covered          100% Covered          100% Covered
# 8          100% Covered      100% Not Covered          100% Covered
# 9           98% Covered           98% Covered           98% Covered
#
#               Rozlytrek                Turalio
# 0           100% Covered           100% Covered
# 1   100% Covered (PA/ST)   100% Covered (PA/ST)
# 2   100% Covered (PA/ST)   100% Covered (PA/ST)
# 3          99% Preferred          99% Preferred
# 4            98% Covered            98% Covered
# 5           100% Covered           100% Covered
# 6   100% Covered (PA/ST)   100% Covered (PA/ST)
# 7         100% Preferred         100% Preferred
# 8           100% Covered           100% Covered
# 9  98% Preferred (PA/ST)  98% Preferred (PA/ST)
#
# [10 rows x 84 columns]

# %%
df_state_medicaid_p = clean_percentage_data(df) # State_medicaid
df_state_medicaid_p
# Out:
# Trade Name  State of Colorado  State of Oklahoma  State of Massachusetts  \
# Vijoice                 100.0              100.0                   100.0
# Fyarro                  100.0              100.0                   100.0
# Carvykti                100.0              100.0                   100.0
# Tecartus                100.0              100.0                   100.0
# Enhertu                 100.0              100.0                   100.0
# ...                       ...                ...                     ...
# Cosela                  100.0              100.0                   100.0
# Jelmyto                 100.0              100.0                   100.0
# Polivy                  100.0              100.0                   100.0
# Rozlytrek               100.0              100.0                   100.0
# Turalio                 100.0              100.0                   100.0
#
# Trade Name  State of California  State of Florida  State of Alabama  \
# Vijoice                    99.0              98.0             100.0
# Fyarro                     99.0              98.0             100.0
# Carvykti                   99.0              98.0             100.0
# Tecartus                   99.0              98.0             100.0
# Enhertu                    99.0              98.0             100.0
# ...                         ...               ...               ...
# Cosela                     99.0              98.0             100.0
# Jelmyto                    99.0              98.0             100.0
# Polivy                     99.0              98.0             100.0
# Rozlytrek                  99.0              98.0             100.0
# Turalio                    99.0              98.0             100.0
#
# Trade Name  State of Arkansas  State of Connecticut  State of Michigan  \
# Vijoice                 100.0                 100.0              100.0
# Fyarro                  100.0                 100.0              100.0
# Carvykti                100.0                 100.0              100.0
# Tecartus                100.0                 100.0              100.0
# Enhertu                 100.0                 100.0              100.0
# ...                       ...                   ...                ...
# Cosela                  100.0                 100.0              100.0
# Jelmyto                 100.0                 100.0              100.0
# Polivy                  100.0                 100.0              100.0
# Rozlytrek               100.0                 100.0              100.0
# Turalio                 100.0                 100.0              100.0
#
# Trade Name  State of Georgia  ...  State of Delaware  State of West Virginia  \
# Vijoice                 98.0  ...              100.0                    99.0
# Fyarro                  98.0  ...              100.0                    99.0
# Carvykti                98.0  ...              100.0                    99.0
# Tecartus                98.0  ...              100.0                    99.0
# Enhertu                 98.0  ...              100.0                    99.0
# ...                      ...  ...                ...                     ...
# Cosela                  98.0  ...              100.0                    99.0
# Jelmyto                 98.0  ...              100.0                    99.0
# Polivy                  98.0  ...              100.0                    99.0
# Rozlytrek               98.0  ...              100.0                    99.0
# Turalio                 98.0  ...              100.0                    99.0
#
# Trade Name  State of Rhode Island  Commonwealth of Puerto Rico  \
# Vijoice                      98.0                        100.0
# Fyarro                       98.0                        100.0
# Carvykti                     98.0                        100.0
# Tecartus                     98.0                        100.0
# Enhertu                      98.0                        100.0
# ...                           ...                          ...
# Cosela                       98.0                        100.0
# Jelmyto                      98.0                        100.0
# Polivy                       98.0                        100.0
# Rozlytrek                    98.0                        100.0
# Turalio                      98.0                        100.0
#
# Trade Name  State of Tennessee  State of New Hampshire  State of Nebraska  \
# Vijoice                  100.0                    91.0               67.0
# Fyarro                   100.0                    91.0              100.0
# Carvykti                 100.0                    91.0              100.0
# Tecartus                 100.0                    91.0               67.0
# Enhertu                  100.0                    91.0               67.0
# ...                        ...                     ...                ...
# Cosela                   100.0                    91.0               67.0
# Jelmyto                  100.0                    91.0               67.0
# Polivy                   100.0                    91.0               67.0
# Rozlytrek                100.0                    91.0               67.0
# Turalio                  100.0                    91.0               67.0
#
# Trade Name  District of Columbia  State of Kansas  State of Hawaii
# Vijoice                    100.0            100.0            100.0
# Fyarro                     100.0            100.0            100.0
# Carvykti                   100.0            100.0            100.0
# Tecartus                   100.0            100.0            100.0
# Enhertu                    100.0            100.0            100.0
# ...                          ...              ...              ...
# Cosela                     100.0            100.0            100.0
# Jelmyto                    100.0            100.0            100.0
# Polivy                     100.0            100.0            100.0
# Rozlytrek                  100.0            100.0            100.0
# Turalio                    100.0            100.0            100.0
#
# [82 rows x 52 columns]

# %%
df_state_medicaid_c = clean_coverage_data(df) # State_medicaid
df_state_medicaid_c
# Out:
# Trade Name State of Colorado State of Oklahoma State of Massachusetts  \
# Vijoice      Covered (PA/ST)       Not Covered      Preferred (PA/ST)
# Fyarro       Covered (PA/ST)       Not Covered        Covered (PA/ST)
# Carvykti     Covered (PA/ST)       Not Covered            Not Covered
# Tecartus     Covered (PA/ST)   Covered (PA/ST)            Not Covered
# Enhertu              Covered   Covered (PA/ST)        Covered (PA/ST)
# ...                      ...               ...                    ...
# Cosela               Covered           Covered        Covered (PA/ST)
# Jelmyto              Covered   Covered (PA/ST)            Not Covered
# Polivy               Covered   Covered (PA/ST)        Covered (PA/ST)
# Rozlytrek            Covered   Covered (PA/ST)        Covered (PA/ST)
# Turalio              Covered   Covered (PA/ST)        Covered (PA/ST)
#
# Trade Name State of California State of Florida State of Alabama  \
# Vijoice        Covered (PA/ST)  Covered (PA/ST)          Covered
# Fyarro               Preferred  Covered (PA/ST)      Not Covered
# Carvykti       Covered (PA/ST)  Covered (PA/ST)          Covered
# Tecartus       Covered (PA/ST)          Covered      Not Covered
# Enhertu              Preferred          Covered          Covered
# ...                        ...              ...              ...
# Cosela         Covered (PA/ST)  Covered (PA/ST)      Not Covered
# Jelmyto              Preferred  Covered (PA/ST)          Covered
# Polivy               Preferred  Covered (PA/ST)          Covered
# Rozlytrek            Preferred          Covered          Covered
# Turalio              Preferred          Covered          Covered
#
# Trade Name State of Arkansas State of Connecticut State of Michigan  \
# Vijoice      Covered (PA/ST)      Covered (PA/ST)   Covered (PA/ST)
# Fyarro       Covered (PA/ST)      Covered (PA/ST)   Covered (PA/ST)
# Carvykti     Covered (PA/ST)      Covered (PA/ST)   Covered (PA/ST)
# Tecartus             Covered              Covered       Not Covered
# Enhertu              Covered              Covered       Not Covered
# ...                      ...                  ...               ...
# Cosela               Covered              Covered           Covered
# Jelmyto              Covered              Covered       Not Covered
# Polivy               Covered              Covered           Covered
# Rozlytrek    Covered (PA/ST)            Preferred           Covered
# Turalio      Covered (PA/ST)            Preferred           Covered
#
# Trade Name   State of Georgia  ...  State of Delaware State of West Virginia  \
# Vijoice       Covered (PA/ST)  ...    Covered (PA/ST)        Covered (PA/ST)
# Fyarro        Covered (PA/ST)  ...        Not Covered        Covered (PA/ST)
# Carvykti      Covered (PA/ST)  ...            Covered        Covered (PA/ST)
# Tecartus              Covered  ...  Preferred (PA/ST)                Covered
# Enhertu               Covered  ...  Preferred (PA/ST)                Covered
# ...                       ...  ...                ...                    ...
# Cosela                Covered  ...            Covered                Covered
# Jelmyto               Covered  ...        Not Covered                Covered
# Polivy                Covered  ...  Preferred (PA/ST)                Covered
# Rozlytrek   Preferred (PA/ST)  ...  Preferred (PA/ST)                Covered
# Turalio     Preferred (PA/ST)  ...            Covered                Covered
#
# Trade Name State of Rhode Island Commonwealth of Puerto Rico  \
# Vijoice          Covered (PA/ST)                 Not Covered
# Fyarro           Covered (PA/ST)                 Not Covered
# Carvykti         Covered (PA/ST)                 Not Covered
# Tecartus                 Covered                 Not Covered
# Enhertu                  Covered                 Not Covered
# ...                          ...                         ...
# Cosela                   Covered                 Not Covered
# Jelmyto                  Covered                 Not Covered
# Polivy                   Covered                 Not Covered
# Rozlytrek                Covered                 Not Covered
# Turalio                  Covered                 Not Covered
#
# Trade Name State of Tennessee State of New Hampshire State of Nebraska  \
# Vijoice           Not Covered        Covered (PA/ST)           Covered
# Fyarro            Not Covered                Covered       Not Covered
# Carvykti          Not Covered        Covered (PA/ST)       Not Covered
# Tecartus          Not Covered                Covered           Covered
# Enhertu           Not Covered                Covered           Covered
# ...                       ...                    ...               ...
# Cosela            Not Covered                Covered           Covered
# Jelmyto           Not Covered                Covered           Covered
# Polivy            Not Covered                Covered           Covered
# Rozlytrek         Not Covered                Covered   Covered (PA/ST)
# Turalio           Not Covered                Covered           Covered
#
# Trade Name District of Columbia State of Kansas State of Hawaii
# Vijoice             Not Covered     Not Covered     Not Covered
# Fyarro              Not Covered     Not Covered     Not Covered
# Carvykti            Not Covered     Not Covered     Not Covered
# Tecartus            Not Covered     Not Covered     Not Covered
# Enhertu             Not Covered     Not Covered     Not Covered
# ...                         ...             ...             ...
# Cosela              Not Covered     Not Covered     Not Covered
# Jelmyto             Not Covered     Not Covered     Not Covered
# Polivy              Not Covered     Not Covered     Not Covered
# Rozlytrek           Not Covered     Not Covered     Not Covered
# Turalio             Not Covered     Not Covered     Not Covered
#
# [82 rows x 52 columns]

# %%
df_state_medicaid_num = get_plans(df) # State_medicaid
df_state_medicaid_num
# Out:
#                       Payer/PBM  # of Plans
# 0             State of Colorado           7
# 1             State of Oklahoma           2
# 2        State of Massachusetts           2
# 3           State of California           2
# 4              State of Florida           2
# 5              State of Alabama           2
# 6             State of Arkansas           2
# 7          State of Connecticut           2
# 8             State of Michigan           2
# 9              State of Georgia           2
# 10            State of New York           2
# 11            State of Illinois           2
# 12               State of Idaho           2
# 13            State of Missouri           2
# 14             State of Montana           2
# 15                State of Ohio           2
# 16         State of Mississippi           2
# 17             State of Arizona           2
# 18               State of Maine           2
# 19              State of Alaska           2
# 20          State of Washington           2
# 21      State of South Carolina           2
# 22           State of Minnesota           2
# 23             State of Vermont           2
# 24      State of North Carolina           2
# 25        State of Pennsylvania           2
# 26               State of Texas           2
# 27           State of Louisiana           2
# 28            State of Kentucky           2
# 29           State of Wisconsin           2
# 30             State of Indiana           2
# 31              State of Oregon           2
# 32              State of Nevada           2
# 33        State of South Dakota           2
# 34                State of Utah           2
# 35        State of North Dakota           2
# 36             State of Wyoming           2
# 37            State of Maryland           2
# 38          State of New Mexico           2
# 39          State of New Jersey           2
# 40            State of Virginia           2
# 41                State of Iowa           2
# 42            State of Delaware           2
# 43       State of West Virginia           2
# 44        State of Rhode Island           2
# 45  Commonwealth of Puerto Rico           1
# 46           State of Tennessee           1
# 47       State of New Hampshire           2
# 48            State of Nebraska           2
# 49         District of Columbia           2
# 50              State of Kansas           1
# 51              State of Hawaii           1

# %% [markdown]
# ## Health_Exchange

# %%
sheet_name = to_process[3]
print (sheet_name)
df = pd.read_excel(input_file,sheet_name = sheet_name)
df.head(10)
# Out:
# Health_Exchange
#                                   Payer/PBM # of Plans              Vijoice   \
# 0                       Centene Corporation   33 plans   82% Covered (PA/ST)
# 1                              Florida Blue    5 plans      100% Not Covered
# 2      Kaiser Foundation Health Plans, Inc.   11 plans   90% Covered (PA/ST)
# 3                             Bright Health   16 plans      100% Not Covered
# 4                           Oscar Insurance   34 plans      100% Not Covered
# 5           Health Care Service Corporation    7 plans      100% Not Covered
# 6                              Anthem, Inc.   20 plans  100% Covered (PA/ST)
# 7                 Blue Shield of California    3 plans          100% Covered
# 8                  Molina Health Care, Inc.   16 plans   68% Covered (PA/ST)
# 9  Blue Cross Blue Shield of North Carolina    2 plans  100% Covered (PA/ST)
#
#                 Fyarro              Carvykti             Tecartus   \
# 0       71% Not Covered       71% Not Covered  77% Covered (PA/ST)
# 1      100% Not Covered      100% Not Covered     100% Not Covered
# 2   90% Covered (PA/ST)  100% Covered (PA/ST)  73% Covered (PA/ST)
# 3      100% Not Covered      100% Not Covered     100% Not Covered
# 4      100% Not Covered      100% Not Covered     100% Not Covered
# 5      100% Not Covered      100% Not Covered     100% Not Covered
# 6  100% Covered (PA/ST)      100% Not Covered     100% Not Covered
# 7      100% Not Covered          100% Covered     100% Not Covered
# 8   68% Covered (PA/ST)   68% Covered (PA/ST)  93% Covered (PA/ST)
# 9  100% Covered (PA/ST)  100% Covered (PA/ST)     100% Not Covered
#
#                Enhertu              Exkivity              Pluvicto   \
# 0   71% Covered (PA/ST)   57% Covered (PA/ST)       98% Not Covered
# 1      100% Not Covered        100% Preferred      100% Not Covered
# 2           76% Covered   81% Covered (PA/ST)      100% Not Covered
# 3      100% Not Covered      100% Not Covered      100% Not Covered
# 4      100% Not Covered      100% Not Covered      100% Not Covered
# 5      100% Not Covered  100% Covered (PA/ST)      100% Not Covered
# 6  100% Covered (PA/ST)  100% Covered (PA/ST)  100% Covered (PA/ST)
# 7      100% Not Covered  100% Covered (PA/ST)      100% Not Covered
# 8   93% Covered (PA/ST)   93% Covered (PA/ST)      100% Not Covered
# 9      100% Not Covered  100% Covered (PA/ST)      100% Not Covered
#
#              Cabometyx   ...              Ayvakit                Tukysa   \
# 0   97% Covered (PA/ST)  ...   82% Covered (PA/ST)  100% Covered (PA/ST)
# 1   86% Covered (PA/ST)  ...   86% Covered (PA/ST)   86% Covered (PA/ST)
# 2           86% Covered  ...   82% Covered (PA/ST)           86% Covered
# 3      100% Not Covered  ...      100% Not Covered      100% Not Covered
# 4       93% Not Covered  ...      100% Not Covered       69% Not Covered
# 5  100% Covered (PA/ST)  ...  100% Covered (PA/ST)   97% Covered (PA/ST)
# 6  100% Covered (PA/ST)  ...  100% Covered (PA/ST)  100% Covered (PA/ST)
# 7  100% Covered (PA/ST)  ...      100% Not Covered      100% Not Covered
# 8  100% Covered (PA/ST)  ...   93% Covered (PA/ST)   93% Covered (PA/ST)
# 9  100% Covered (PA/ST)  ...  100% Covered (PA/ST)  100% Covered (PA/ST)
#
#                Qinlock              Bavencio              Blincyto   \
# 0   82% Covered (PA/ST)   67% Covered (PA/ST)      100% Not Covered
# 1   86% Covered (PA/ST)      100% Not Covered      100% Not Covered
# 2   77% Covered (PA/ST)   73% Covered (PA/ST)           76% Covered
# 3      100% Not Covered      100% Not Covered      100% Not Covered
# 4      100% Not Covered      100% Not Covered      100% Not Covered
# 5  100% Covered (PA/ST)      100% Not Covered      100% Not Covered
# 6  100% Covered (PA/ST)  100% Covered (PA/ST)  100% Covered (PA/ST)
# 7      100% Not Covered      100% Not Covered      100% Not Covered
# 8   93% Covered (PA/ST)   93% Covered (PA/ST)   93% Covered (PA/ST)
# 9      100% Not Covered      100% Not Covered      100% Not Covered
#
#                 Cosela               Jelmyto                Polivy   \
# 0      100% Not Covered   71% Covered (PA/ST)   66% Covered (PA/ST)
# 1      100% Not Covered      100% Not Covered      100% Not Covered
# 2   73% Covered (PA/ST)       85% Not Covered   73% Covered (PA/ST)
# 3      100% Not Covered      100% Not Covered      100% Not Covered
# 4      100% Not Covered      100% Not Covered      100% Not Covered
# 5      100% Not Covered      100% Not Covered      100% Not Covered
# 6  100% Covered (PA/ST)  100% Covered (PA/ST)  100% Covered (PA/ST)
# 7      100% Not Covered      100% Not Covered      100% Not Covered
# 8   93% Covered (PA/ST)   93% Covered (PA/ST)   93% Covered (PA/ST)
# 9      100% Not Covered      100% Not Covered      100% Not Covered
#
#              Rozlytrek               Turalio
# 0   82% Covered (PA/ST)   81% Covered (PA/ST)
# 1   86% Covered (PA/ST)   86% Covered (PA/ST)
# 2           86% Covered   81% Covered (PA/ST)
# 3      100% Not Covered      100% Not Covered
# 4      100% Not Covered      100% Not Covered
# 5  100% Covered (PA/ST)   83% Covered (PA/ST)
# 6  100% Covered (PA/ST)  100% Covered (PA/ST)
# 7      100% Not Covered      100% Not Covered
# 8   93% Covered (PA/ST)   93% Covered (PA/ST)
# 9  100% Covered (PA/ST)  100% Covered (PA/ST)
#
# [10 rows x 84 columns]

# %%
df_health_exchange_p = clean_percentage_data(df) # Health_Exchange
df_health_exchange_p
# Out:
# Trade Name  Centene Corporation  Florida Blue  \
# Vijoice                    82.0         100.0
# Fyarro                     71.0         100.0
# Carvykti                   71.0         100.0
# Tecartus                   77.0         100.0
# Enhertu                    71.0         100.0
# ...                         ...           ...
# Cosela                    100.0         100.0
# Jelmyto                    71.0         100.0
# Polivy                     66.0         100.0
# Rozlytrek                  82.0          86.0
# Turalio                    81.0          86.0
#
# Trade Name  Kaiser Foundation Health Plans, Inc.  Bright Health  \
# Vijoice                                     90.0          100.0
# Fyarro                                      90.0          100.0
# Carvykti                                   100.0          100.0
# Tecartus                                    73.0          100.0
# Enhertu                                     76.0          100.0
# ...                                          ...            ...
# Cosela                                      73.0          100.0
# Jelmyto                                     85.0          100.0
# Polivy                                      73.0          100.0
# Rozlytrek                                   86.0          100.0
# Turalio                                     81.0          100.0
#
# Trade Name  Oscar Insurance  Health Care Service Corporation  Anthem, Inc.  \
# Vijoice               100.0                            100.0         100.0
# Fyarro                100.0                            100.0         100.0
# Carvykti              100.0                            100.0         100.0
# Tecartus              100.0                            100.0         100.0
# Enhertu               100.0                            100.0         100.0
# ...                     ...                              ...           ...
# Cosela                100.0                            100.0         100.0
# Jelmyto               100.0                            100.0         100.0
# Polivy                100.0                            100.0         100.0
# Rozlytrek             100.0                            100.0         100.0
# Turalio               100.0                             83.0         100.0
#
# Trade Name  Blue Shield of California  Molina Health Care, Inc.  \
# Vijoice                         100.0                      68.0
# Fyarro                          100.0                      68.0
# Carvykti                        100.0                      68.0
# Tecartus                        100.0                      93.0
# Enhertu                         100.0                      93.0
# ...                               ...                       ...
# Cosela                          100.0                      93.0
# Jelmyto                         100.0                      93.0
# Polivy                          100.0                      93.0
# Rozlytrek                       100.0                      93.0
# Turalio                         100.0                      93.0
#
# Trade Name  Blue Cross Blue Shield of North Carolina  ...  \
# Vijoice                                        100.0  ...
# Fyarro                                         100.0  ...
# Carvykti                                       100.0  ...
# Tecartus                                       100.0  ...
# Enhertu                                        100.0  ...
# ...                                              ...  ...
# Cosela                                         100.0  ...
# Jelmyto                                        100.0  ...
# Polivy                                         100.0  ...
# Rozlytrek                                      100.0  ...
# Turalio                                        100.0  ...
#
# Trade Name  McLaren Health Care Corporation  Capital Health Plan  \
# Vijoice                               100.0                100.0
# Fyarro                                100.0                100.0
# Carvykti                              100.0                100.0
# Tecartus                              100.0                100.0
# Enhertu                               100.0                100.0
# ...                                     ...                  ...
# Cosela                                100.0                100.0
# Jelmyto                               100.0                100.0
# Polivy                                100.0                100.0
# Rozlytrek                             100.0                100.0
# Turalio                               100.0                100.0
#
# Trade Name  Renown Health  Chinese Community Health Plan Corporation  \
# Vijoice             100.0                                      100.0
# Fyarro              100.0                                      100.0
# Carvykti            100.0                                      100.0
# Tecartus            100.0                                      100.0
# Enhertu             100.0                                      100.0
# ...                   ...                                        ...
# Cosela              100.0                                      100.0
# Jelmyto             100.0                                      100.0
# Polivy              100.0                                      100.0
# Rozlytrek           100.0                                      100.0
# Turalio             100.0                                      100.0
#
# Trade Name  Community Care, Inc.  Community Health Network of Washington  \
# Vijoice                    100.0                                   100.0
# Fyarro                     100.0                                   100.0
# Carvykti                   100.0                                   100.0
# Tecartus                   100.0                                   100.0
# Enhertu                    100.0                                   100.0
# ...                          ...                                     ...
# Cosela                     100.0                                   100.0
# Jelmyto                    100.0                                   100.0
# Polivy                     100.0                                   100.0
# Rozlytrek                  100.0                                   100.0
# Turalio                    100.0                                   100.0
#
# Trade Name  Wisconsin Physicians Service Insurance Corporation  Cox Health  \
# Vijoice                                                 100.0        100.0
# Fyarro                                                  100.0        100.0
# Carvykti                                                100.0        100.0
# Tecartus                                                100.0        100.0
# Enhertu                                                 100.0        100.0
# ...                                                       ...          ...
# Cosela                                                  100.0        100.0
# Jelmyto                                                 100.0        100.0
# Polivy                                                  100.0        100.0
# Rozlytrek                                               100.0        100.0
# Turalio                                                 100.0        100.0
#
# Trade Name  Paramount Health Care, Inc.  Denver Health Medical Plan
# Vijoice                           100.0                       100.0
# Fyarro                            100.0                       100.0
# Carvykti                          100.0                       100.0
# Tecartus                          100.0                       100.0
# Enhertu                           100.0                       100.0
# ...                                 ...                         ...
# Cosela                            100.0                       100.0
# Jelmyto                           100.0                       100.0
# Polivy                            100.0                       100.0
# Rozlytrek                         100.0                       100.0
# Turalio                           100.0                       100.0
#
# [82 rows x 108 columns]

# %%
df_health_exchange_c = clean_coverage_data(df) # Health_Exchange
df_health_exchange_c
# Out:
# Trade Name Centene Corporation     Florida Blue  \
# Vijoice        Covered (PA/ST)      Not Covered
# Fyarro             Not Covered      Not Covered
# Carvykti           Not Covered      Not Covered
# Tecartus       Covered (PA/ST)      Not Covered
# Enhertu        Covered (PA/ST)      Not Covered
# ...                        ...              ...
# Cosela             Not Covered      Not Covered
# Jelmyto        Covered (PA/ST)      Not Covered
# Polivy         Covered (PA/ST)      Not Covered
# Rozlytrek      Covered (PA/ST)  Covered (PA/ST)
# Turalio        Covered (PA/ST)  Covered (PA/ST)
#
# Trade Name Kaiser Foundation Health Plans, Inc. Bright Health Oscar Insurance  \
# Vijoice                         Covered (PA/ST)   Not Covered     Not Covered
# Fyarro                          Covered (PA/ST)   Not Covered     Not Covered
# Carvykti                        Covered (PA/ST)   Not Covered     Not Covered
# Tecartus                        Covered (PA/ST)   Not Covered     Not Covered
# Enhertu                                 Covered   Not Covered     Not Covered
# ...                                         ...           ...             ...
# Cosela                          Covered (PA/ST)   Not Covered     Not Covered
# Jelmyto                             Not Covered   Not Covered     Not Covered
# Polivy                          Covered (PA/ST)   Not Covered     Not Covered
# Rozlytrek                               Covered   Not Covered     Not Covered
# Turalio                         Covered (PA/ST)   Not Covered     Not Covered
#
# Trade Name Health Care Service Corporation     Anthem, Inc.  \
# Vijoice                        Not Covered  Covered (PA/ST)
# Fyarro                         Not Covered  Covered (PA/ST)
# Carvykti                       Not Covered      Not Covered
# Tecartus                       Not Covered      Not Covered
# Enhertu                        Not Covered  Covered (PA/ST)
# ...                                    ...              ...
# Cosela                         Not Covered  Covered (PA/ST)
# Jelmyto                        Not Covered  Covered (PA/ST)
# Polivy                         Not Covered  Covered (PA/ST)
# Rozlytrek                  Covered (PA/ST)  Covered (PA/ST)
# Turalio                    Covered (PA/ST)  Covered (PA/ST)
#
# Trade Name Blue Shield of California Molina Health Care, Inc.  \
# Vijoice                      Covered          Covered (PA/ST)
# Fyarro                   Not Covered          Covered (PA/ST)
# Carvykti                     Covered          Covered (PA/ST)
# Tecartus                 Not Covered          Covered (PA/ST)
# Enhertu                  Not Covered          Covered (PA/ST)
# ...                              ...                      ...
# Cosela                   Not Covered          Covered (PA/ST)
# Jelmyto                  Not Covered          Covered (PA/ST)
# Polivy                   Not Covered          Covered (PA/ST)
# Rozlytrek                Not Covered          Covered (PA/ST)
# Turalio                  Not Covered          Covered (PA/ST)
#
# Trade Name Blue Cross Blue Shield of North Carolina  ... Capital Health Plan  \
# Vijoice                             Covered (PA/ST)  ...         Not Covered
# Fyarro                              Covered (PA/ST)  ...         Not Covered
# Carvykti                            Covered (PA/ST)  ...         Not Covered
# Tecartus                                Not Covered  ...         Not Covered
# Enhertu                                 Not Covered  ...         Not Covered
# ...                                             ...  ...                 ...
# Cosela                                  Not Covered  ...         Not Covered
# Jelmyto                                 Not Covered  ...         Not Covered
# Polivy                                  Not Covered  ...         Not Covered
# Rozlytrek                           Covered (PA/ST)  ...     Covered (PA/ST)
# Turalio                             Covered (PA/ST)  ...     Covered (PA/ST)
#
# Trade Name    Renown Health Chinese Community Health Plan Corporation  \
# Vijoice     Covered (PA/ST)                               Not Covered
# Fyarro      Covered (PA/ST)                               Not Covered
# Carvykti    Covered (PA/ST)                               Not Covered
# Tecartus    Covered (PA/ST)                               Not Covered
# Enhertu     Covered (PA/ST)                               Not Covered
# ...                     ...                                       ...
# Cosela          Not Covered                               Not Covered
# Jelmyto     Covered (PA/ST)                               Not Covered
# Polivy      Covered (PA/ST)                               Not Covered
# Rozlytrek   Covered (PA/ST)                               Not Covered
# Turalio     Covered (PA/ST)                               Not Covered
#
# Trade Name Community Care, Inc. Community Health Network of Washington  \
# Vijoice             Not Covered                        Covered (PA/ST)
# Fyarro              Not Covered                        Covered (PA/ST)
# Carvykti            Not Covered                        Covered (PA/ST)
# Tecartus            Not Covered                        Covered (PA/ST)
# Enhertu             Not Covered                        Covered (PA/ST)
# ...                         ...                                    ...
# Cosela              Not Covered                        Covered (PA/ST)
# Jelmyto             Not Covered                        Covered (PA/ST)
# Polivy              Not Covered                        Covered (PA/ST)
# Rozlytrek           Not Covered                        Covered (PA/ST)
# Turalio             Not Covered                        Covered (PA/ST)
#
# Trade Name Wisconsin Physicians Service Insurance Corporation  \
# Vijoice                                       Covered (PA/ST)
# Fyarro                                        Covered (PA/ST)
# Carvykti                                          Not Covered
# Tecartus                                      Covered (PA/ST)
# Enhertu                                       Covered (PA/ST)
# ...                                                       ...
# Cosela                                            Not Covered
# Jelmyto                                       Covered (PA/ST)
# Polivy                                        Covered (PA/ST)
# Rozlytrek                                     Covered (PA/ST)
# Turalio                                       Covered (PA/ST)
#
# Trade Name         Cox Health Paramount Health Care, Inc.  \
# Vijoice     Preferred (PA/ST)             Covered (PA/ST)
# Fyarro            Not Covered             Covered (PA/ST)
# Carvykti          Not Covered             Covered (PA/ST)
# Tecartus          Not Covered                     Covered
# Enhertu           Not Covered                     Covered
# ...                       ...                         ...
# Cosela                Covered                     Covered
# Jelmyto           Not Covered                     Covered
# Polivy            Not Covered                     Covered
# Rozlytrek     Covered (PA/ST)                     Covered
# Turalio       Covered (PA/ST)                     Covered
#
# Trade Name Denver Health Medical Plan        Ascension
# Vijoice               Covered (PA/ST)  Covered (PA/ST)
# Fyarro                    Not Covered  Covered (PA/ST)
# Carvykti                  Not Covered          Covered
# Tecartus                      Covered      Not Covered
# Enhertu                       Covered      Not Covered
# ...                               ...              ...
# Cosela                        Covered      Not Covered
# Jelmyto               Covered (PA/ST)      Not Covered
# Polivy                        Covered      Not Covered
# Rozlytrek             Covered (PA/ST)  Covered (PA/ST)
# Turalio               Covered (PA/ST)      Not Covered
#
# [82 rows x 109 columns]

# %%
df_health_exchange_num = get_plans(df) # Health_Exchange
df_health_exchange_num
# Out:
#                                              Payer/PBM  # of Plans
# 0                                  Centene Corporation          33
# 1                                         Florida Blue           5
# 2                 Kaiser Foundation Health Plans, Inc.          11
# 3                                        Bright Health          16
# 4                                      Oscar Insurance          34
# ..                                                 ...         ...
# 104  Wisconsin Physicians Service Insurance Corpora...           3
# 105                                         Cox Health           1
# 106                        Paramount Health Care, Inc.           1
# 107                         Denver Health Medical Plan           2
# 108                                          Ascension           2
#
# [109 rows x 2 columns]

# %% [markdown]
# ## Managed medicaid

# %%
sheet_name = to_process[4]
print (sheet_name)
df = pd.read_excel(input_file,sheet_name = sheet_name)
df.head(10)
# Out:
# Managed medicaid
#                   Payer/PBM # of Plans              Vijoice   \
# 0       State of California   24 plans  100% Covered (PA/ST)
# 1       Centene Corporation   24 plans   56% Covered (PA/ST)
# 2            State of Texas   44 plans           98% Covered
# 3          State of Florida   12 plans  100% Covered (PA/ST)
# 4              Anthem, Inc.   16 plans   94% Covered (PA/ST)
# 5     State of Pennsylvania   10 plans  100% Covered (PA/ST)
# 6  UnitedHealth Group, Inc.   23 plans   81% Covered (PA/ST)
# 7             State of Ohio    5 plans  100% Covered (PA/ST)
# 8  Molina Health Care, Inc.   15 plans   57% Covered (PA/ST)
# 9   State of North Carolina    6 plans          100% Covered
#
#                 Fyarro              Carvykti              Tecartus   \
# 0        100% Preferred  100% Covered (PA/ST)  100% Covered (PA/ST)
# 1   59% Covered (PA/ST)   78% Covered (PA/ST)   58% Covered (PA/ST)
# 2      100% Not Covered      100% Not Covered           98% Covered
# 3  100% Covered (PA/ST)  100% Covered (PA/ST)          100% Covered
# 4  100% Covered (PA/ST)   71% Covered (PA/ST)   71% Covered (PA/ST)
# 5   79% Covered (PA/ST)   79% Covered (PA/ST)   67% Covered (PA/ST)
# 6       72% Not Covered       73% Not Covered       81% Not Covered
# 7   87% Covered (PA/ST)   87% Covered (PA/ST)   87% Covered (PA/ST)
# 8   58% Covered (PA/ST)   63% Covered (PA/ST)       61% Not Covered
# 9           62% Covered       83% Not Covered       83% Not Covered
#
#                 Enhertu              Exkivity              Pluvicto   \
# 0         100% Preferred        100% Preferred      100% Not Covered
# 1    70% Covered (PA/ST)   64% Covered (PA/ST)   88% Covered (PA/ST)
# 2            98% Covered        100% Preferred      100% Not Covered
# 3           100% Covered  100% Covered (PA/ST)      100% Not Covered
# 4    94% Covered (PA/ST)   94% Covered (PA/ST)   94% Covered (PA/ST)
# 5   100% Covered (PA/ST)   79% Covered (PA/ST)  100% Covered (PA/ST)
# 6        84% Not Covered   90% Covered (PA/ST)   81% Covered (PA/ST)
# 7  49% Preferred (PA/ST)  100% Covered (PA/ST)       51% Not Covered
# 8    47% Covered (PA/ST)   47% Covered (PA/ST)       53% Not Covered
# 9           100% Covered          100% Covered       62% Not Covered
#
#                Cabometyx   ...                Ayvakit   \
# 0          100% Preferred  ...          100% Preferred
# 1     69% Covered (PA/ST)  ...     68% Covered (PA/ST)
# 2          100% Preferred  ...          100% Preferred
# 3    100% Covered (PA/ST)  ...            100% Covered
# 4     94% Covered (PA/ST)  ...     94% Covered (PA/ST)
# 5  100% Preferred (PA/ST)  ...  100% Preferred (PA/ST)
# 6   84% Preferred (PA/ST)  ...     81% Covered (PA/ST)
# 7     87% Covered (PA/ST)  ...    100% Covered (PA/ST)
# 8     47% Covered (PA/ST)  ...     47% Covered (PA/ST)
# 9     62% Covered (PA/ST)  ...     62% Covered (PA/ST)
#
#                   Tukysa               Qinlock              Bavencio   \
# 0    100% Covered (PA/ST)   82% Covered (PA/ST)        100% Preferred
# 1     70% Covered (PA/ST)   86% Covered (PA/ST)   70% Covered (PA/ST)
# 2          100% Preferred   77% Covered (PA/ST)           98% Covered
# 3            100% Covered      100% Not Covered  100% Covered (PA/ST)
# 4     94% Covered (PA/ST)      100% Not Covered   94% Covered (PA/ST)
# 5  100% Preferred (PA/ST)  100% Covered (PA/ST)  100% Covered (PA/ST)
# 6     81% Covered (PA/ST)  100% Covered (PA/ST)       84% Not Covered
# 7     51% Covered (PA/ST)      100% Not Covered   87% Covered (PA/ST)
# 8     47% Covered (PA/ST)   93% Covered (PA/ST)   47% Covered (PA/ST)
# 9            100% Covered      100% Not Covered          100% Covered
#
#               Blincyto                 Cosela                Jelmyto   \
# 0        100% Preferred   100% Covered (PA/ST)         100% Preferred
# 1   70% Covered (PA/ST)    88% Covered (PA/ST)    70% Covered (PA/ST)
# 2           98% Covered            82% Covered            72% Covered
# 3  100% Covered (PA/ST)   100% Covered (PA/ST)   100% Covered (PA/ST)
# 4   94% Covered (PA/ST)  66% Preferred (PA/ST)    94% Covered (PA/ST)
# 5  100% Covered (PA/ST)    67% Covered (PA/ST)    67% Covered (PA/ST)
# 6       84% Not Covered    81% Covered (PA/ST)        83% Not Covered
# 7   87% Covered (PA/ST)   100% Covered (PA/ST)  49% Preferred (PA/ST)
# 8   47% Covered (PA/ST)    47% Covered (PA/ST)    47% Covered (PA/ST)
# 9           79% Covered            62% Covered           100% Covered
#
#                 Polivy               Rozlytrek                 Turalio
# 0        100% Preferred          100% Preferred          100% Preferred
# 1   69% Covered (PA/ST)     70% Covered (PA/ST)     73% Covered (PA/ST)
# 2           98% Covered          100% Preferred             98% Covered
# 3  100% Covered (PA/ST)            100% Covered            100% Covered
# 4   94% Covered (PA/ST)     94% Covered (PA/ST)     94% Covered (PA/ST)
# 5  100% Covered (PA/ST)  100% Preferred (PA/ST)  100% Preferred (PA/ST)
# 6       73% Not Covered   78% Preferred (PA/ST)   78% Preferred (PA/ST)
# 7   87% Covered (PA/ST)   62% Preferred (PA/ST)   62% Preferred (PA/ST)
# 8   47% Covered (PA/ST)   49% Preferred (PA/ST)   49% Preferred (PA/ST)
# 9          100% Covered            100% Covered            100% Covered
#
# [10 rows x 84 columns]

# %%
df_managed_medicaid_p = clean_percentage_data(df) # Managed medicaid
df_managed_medicaid_p
# Out:
# Trade Name  State of California  Centene Corporation  State of Texas  \
# Vijoice                   100.0                 56.0            98.0
# Fyarro                    100.0                 59.0           100.0
# Carvykti                  100.0                 78.0           100.0
# Tecartus                  100.0                 58.0            98.0
# Enhertu                   100.0                 70.0            98.0
# ...                         ...                  ...             ...
# Cosela                    100.0                 88.0            82.0
# Jelmyto                   100.0                 70.0            72.0
# Polivy                    100.0                 69.0            98.0
# Rozlytrek                 100.0                 70.0           100.0
# Turalio                   100.0                 73.0            98.0
#
# Trade Name  State of Florida  Anthem, Inc.  State of Pennsylvania  \
# Vijoice                100.0          94.0                  100.0
# Fyarro                 100.0         100.0                   79.0
# Carvykti               100.0          71.0                   79.0
# Tecartus               100.0          71.0                   67.0
# Enhertu                100.0          94.0                  100.0
# ...                      ...           ...                    ...
# Cosela                 100.0          66.0                   67.0
# Jelmyto                100.0          94.0                   67.0
# Polivy                 100.0          94.0                  100.0
# Rozlytrek              100.0          94.0                  100.0
# Turalio                100.0          94.0                  100.0
#
# Trade Name  UnitedHealth Group, Inc.  State of Ohio  Molina Health Care, Inc.  \
# Vijoice                         81.0          100.0                      57.0
# Fyarro                          72.0           87.0                      58.0
# Carvykti                        73.0           87.0                      63.0
# Tecartus                        81.0           87.0                      61.0
# Enhertu                         84.0           49.0                      47.0
# ...                              ...            ...                       ...
# Cosela                          81.0          100.0                      47.0
# Jelmyto                         83.0           49.0                      47.0
# Polivy                          73.0           87.0                      47.0
# Rozlytrek                       78.0           62.0                      49.0
# Turalio                         78.0           62.0                      49.0
#
# Trade Name  State of North Carolina  ...  \
# Vijoice                       100.0  ...
# Fyarro                         62.0  ...
# Carvykti                       83.0  ...
# Tecartus                       83.0  ...
# Enhertu                       100.0  ...
# ...                             ...  ...
# Cosela                         62.0  ...
# Jelmyto                       100.0  ...
# Polivy                        100.0  ...
# Rozlytrek                     100.0  ...
# Turalio                       100.0  ...
#
# Trade Name  Western Oregon Advanced Health, LLC.  Merle West Medical Center  \
# Vijoice                                    100.0                      100.0
# Fyarro                                     100.0                      100.0
# Carvykti                                   100.0                      100.0
# Tecartus                                   100.0                      100.0
# Enhertu                                    100.0                      100.0
# ...                                          ...                        ...
# Cosela                                     100.0                      100.0
# Jelmyto                                    100.0                      100.0
# Polivy                                     100.0                      100.0
# Rozlytrek                                  100.0                      100.0
# Turalio                                    100.0                      100.0
#
# Trade Name  Geisinger Health System Corporation  Humana, Inc.  \
# Vijoice                                   100.0         100.0
# Fyarro                                    100.0         100.0
# Carvykti                                  100.0         100.0
# Tecartus                                  100.0         100.0
# Enhertu                                   100.0         100.0
# ...                                         ...           ...
# Cosela                                    100.0         100.0
# Jelmyto                                   100.0         100.0
# Polivy                                    100.0         100.0
# Rozlytrek                                 100.0         100.0
# Turalio                                   100.0         100.0
#
# Trade Name  ITASCA Medical Care  Amida Care, Inc.  Health Partners Plans  \
# Vijoice                   100.0             100.0                  100.0
# Fyarro                    100.0             100.0                  100.0
# Carvykti                  100.0             100.0                  100.0
# Tecartus                  100.0             100.0                  100.0
# Enhertu                   100.0             100.0                  100.0
# ...                         ...               ...                    ...
# Cosela                    100.0             100.0                  100.0
# Jelmyto                   100.0             100.0                  100.0
# Polivy                    100.0             100.0                  100.0
# Rozlytrek                 100.0             100.0                  100.0
# Turalio                   100.0             100.0                  100.0
#
# Trade Name  Visiting Nurse Service of New York  Medica Health Plans  \
# Vijoice                                  100.0                100.0
# Fyarro                                   100.0                100.0
# Carvykti                                 100.0                100.0
# Tecartus                                 100.0                100.0
# Enhertu                                  100.0                100.0
# ...                                        ...                  ...
# Cosela                                   100.0                100.0
# Jelmyto                                  100.0                100.0
# Polivy                                   100.0                100.0
# Rozlytrek                                100.0                100.0
# Turalio                                  100.0                100.0
#
# Trade Name  Providence Health System
# Vijoice                        100.0
# Fyarro                         100.0
# Carvykti                       100.0
# Tecartus                       100.0
# Enhertu                        100.0
# ...                              ...
# Cosela                         100.0
# Jelmyto                        100.0
# Polivy                         100.0
# Rozlytrek                      100.0
# Turalio                        100.0
#
# [82 rows x 93 columns]

# %%
df_managed_medicaid_c = clean_coverage_data(df) # Managed medicaid
df_managed_medicaid_c
# Out:
# Trade Name State of California Centene Corporation State of Texas  \
# Vijoice        Covered (PA/ST)     Covered (PA/ST)        Covered
# Fyarro               Preferred     Covered (PA/ST)    Not Covered
# Carvykti       Covered (PA/ST)     Covered (PA/ST)    Not Covered
# Tecartus       Covered (PA/ST)     Covered (PA/ST)        Covered
# Enhertu              Preferred     Covered (PA/ST)        Covered
# ...                        ...                 ...            ...
# Cosela         Covered (PA/ST)     Covered (PA/ST)        Covered
# Jelmyto              Preferred     Covered (PA/ST)        Covered
# Polivy               Preferred     Covered (PA/ST)        Covered
# Rozlytrek            Preferred     Covered (PA/ST)      Preferred
# Turalio              Preferred     Covered (PA/ST)        Covered
#
# Trade Name State of Florida       Anthem, Inc. State of Pennsylvania  \
# Vijoice     Covered (PA/ST)    Covered (PA/ST)       Covered (PA/ST)
# Fyarro      Covered (PA/ST)    Covered (PA/ST)       Covered (PA/ST)
# Carvykti    Covered (PA/ST)    Covered (PA/ST)       Covered (PA/ST)
# Tecartus            Covered    Covered (PA/ST)       Covered (PA/ST)
# Enhertu             Covered    Covered (PA/ST)       Covered (PA/ST)
# ...                     ...                ...                   ...
# Cosela      Covered (PA/ST)  Preferred (PA/ST)       Covered (PA/ST)
# Jelmyto     Covered (PA/ST)    Covered (PA/ST)       Covered (PA/ST)
# Polivy      Covered (PA/ST)    Covered (PA/ST)       Covered (PA/ST)
# Rozlytrek           Covered    Covered (PA/ST)     Preferred (PA/ST)
# Turalio             Covered    Covered (PA/ST)     Preferred (PA/ST)
#
# Trade Name UnitedHealth Group, Inc.      State of Ohio  \
# Vijoice             Covered (PA/ST)    Covered (PA/ST)
# Fyarro                  Not Covered    Covered (PA/ST)
# Carvykti                Not Covered    Covered (PA/ST)
# Tecartus                Not Covered    Covered (PA/ST)
# Enhertu                 Not Covered  Preferred (PA/ST)
# ...                             ...                ...
# Cosela              Covered (PA/ST)    Covered (PA/ST)
# Jelmyto                 Not Covered  Preferred (PA/ST)
# Polivy                  Not Covered    Covered (PA/ST)
# Rozlytrek         Preferred (PA/ST)  Preferred (PA/ST)
# Turalio           Preferred (PA/ST)  Preferred (PA/ST)
#
# Trade Name Molina Health Care, Inc. State of North Carolina  ...  \
# Vijoice             Covered (PA/ST)                 Covered  ...
# Fyarro              Covered (PA/ST)                 Covered  ...
# Carvykti            Covered (PA/ST)             Not Covered  ...
# Tecartus                Not Covered             Not Covered  ...
# Enhertu             Covered (PA/ST)                 Covered  ...
# ...                             ...                     ...  ...
# Cosela              Covered (PA/ST)                 Covered  ...
# Jelmyto             Covered (PA/ST)                 Covered  ...
# Polivy              Covered (PA/ST)                 Covered  ...
# Rozlytrek         Preferred (PA/ST)                 Covered  ...
# Turalio           Preferred (PA/ST)                 Covered  ...
#
# Trade Name Western Oregon Advanced Health, LLC. Merle West Medical Center  \
# Vijoice                         Covered (PA/ST)           Covered (PA/ST)
# Fyarro                              Not Covered           Covered (PA/ST)
# Carvykti                        Covered (PA/ST)           Covered (PA/ST)
# Tecartus                        Covered (PA/ST)           Covered (PA/ST)
# Enhertu                         Covered (PA/ST)           Covered (PA/ST)
# ...                                         ...                       ...
# Cosela                          Covered (PA/ST)           Covered (PA/ST)
# Jelmyto                         Covered (PA/ST)           Covered (PA/ST)
# Polivy                          Covered (PA/ST)           Covered (PA/ST)
# Rozlytrek                       Covered (PA/ST)           Covered (PA/ST)
# Turalio                         Covered (PA/ST)               Not Covered
#
# Trade Name Geisinger Health System Corporation       Humana, Inc.  \
# Vijoice                      Preferred (PA/ST)    Covered (PA/ST)
# Fyarro                       Preferred (PA/ST)    Covered (PA/ST)
# Carvykti                     Preferred (PA/ST)    Covered (PA/ST)
# Tecartus                       Covered (PA/ST)    Covered (PA/ST)
# Enhertu                      Preferred (PA/ST)    Covered (PA/ST)
# ...                                        ...                ...
# Cosela                         Covered (PA/ST)    Covered (PA/ST)
# Jelmyto                        Covered (PA/ST)    Covered (PA/ST)
# Polivy                       Preferred (PA/ST)    Covered (PA/ST)
# Rozlytrek                    Preferred (PA/ST)  Preferred (PA/ST)
# Turalio                      Preferred (PA/ST)  Preferred (PA/ST)
#
# Trade Name ITASCA Medical Care   Amida Care, Inc. Health Partners Plans  \
# Vijoice            Not Covered        Not Covered       Covered (PA/ST)
# Fyarro             Not Covered        Not Covered       Covered (PA/ST)
# Carvykti       Covered (PA/ST)    Covered (PA/ST)       Covered (PA/ST)
# Tecartus       Covered (PA/ST)    Covered (PA/ST)       Covered (PA/ST)
# Enhertu        Covered (PA/ST)    Covered (PA/ST)       Covered (PA/ST)
# ...                        ...                ...                   ...
# Cosela         Covered (PA/ST)    Covered (PA/ST)       Covered (PA/ST)
# Jelmyto        Covered (PA/ST)    Covered (PA/ST)       Covered (PA/ST)
# Polivy         Covered (PA/ST)    Covered (PA/ST)       Covered (PA/ST)
# Rozlytrek      Covered (PA/ST)  Preferred (PA/ST)     Preferred (PA/ST)
# Turalio        Covered (PA/ST)  Preferred (PA/ST)     Preferred (PA/ST)
#
# Trade Name Visiting Nurse Service of New York Medica Health Plans  \
# Vijoice                       Covered (PA/ST)             Covered
# Fyarro                        Covered (PA/ST)         Not Covered
# Carvykti                      Covered (PA/ST)     Covered (PA/ST)
# Tecartus                              Covered     Covered (PA/ST)
# Enhertu                               Covered     Covered (PA/ST)
# ...                                       ...                 ...
# Cosela                                Covered     Covered (PA/ST)
# Jelmyto                               Covered     Covered (PA/ST)
# Polivy                                Covered     Covered (PA/ST)
# Rozlytrek                   Preferred (PA/ST)             Covered
# Turalio                     Preferred (PA/ST)     Covered (PA/ST)
#
# Trade Name Providence Health System
# Vijoice             Covered (PA/ST)
# Fyarro                  Not Covered
# Carvykti            Covered (PA/ST)
# Tecartus            Covered (PA/ST)
# Enhertu             Covered (PA/ST)
# ...                             ...
# Cosela              Covered (PA/ST)
# Jelmyto             Covered (PA/ST)
# Polivy              Covered (PA/ST)
# Rozlytrek         Preferred (PA/ST)
# Turalio           Preferred (PA/ST)
#
# [82 rows x 93 columns]

# %%
df_managed_medicaid_num = get_plans(df) # Managed medicaid
df_managed_medicaid_num
# Out:
#                              Payer/PBM  # of Plans
# 0                  State of California          24
# 1                  Centene Corporation          24
# 2                       State of Texas          44
# 3                     State of Florida          12
# 4                         Anthem, Inc.          16
# ..                                 ...         ...
# 88                    Amida Care, Inc.           1
# 89               Health Partners Plans           1
# 90  Visiting Nurse Service of New York           1
# 91                 Medica Health Plans           2
# 92            Providence Health System           1
#
# [93 rows x 2 columns]

# %%
writer = pd.ExcelWriter('output.xlsx')

melt(df_commercial_p).to_excel(writer, 'commercial %')
melt(df_commercial_c).to_excel(writer, 'commercial_coverage')
df_commercial_num.to_excel(writer, 'commercial_plans_list')

melt(df_medicare_p).to_excel(writer, 'medicare %')
melt(df_medicare_c).to_excel(writer, 'medicare_coverage')
df_medicare_num.to_excel(writer, 'medicare_plans_list')

melt(df_state_medicaid_p).to_excel(writer, 'state_medicaid %')
melt(df_state_medicaid_c).to_excel(writer, 'state_medicaid_coverage')
df_state_medicaid_num.to_excel(writer, 'state_medicaid_plans_list')

melt(df_health_exchange_p).to_excel(writer, 'health_exchange %')
melt(df_health_exchange_c).to_excel(writer, 'health_exchange_coverage')
df_health_exchange_num.to_excel(writer, 'health_exchange_plans_list')

melt(df_managed_medicaid_p).to_excel(writer, 'managed_medicaid %')
melt(df_managed_medicaid_c).to_excel(writer, 'managed_medicaid_coverage')
df_managed_medicaid_num.to_excel(writer, 'managed_medicaid_plans_list')

writer.save()
